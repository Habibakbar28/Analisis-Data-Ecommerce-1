# %% [markdown]
# # Proyek Analisis Data : Bike-sharing-dataset
# - **Nama** : Habib Akbar Wibowo
# - **Email** : akbarhabib2800@gmail.com
# - **ID Dicoding** : habibakbar

# %% [markdown]
# # Menentukan Pertanyaan Bisnis
# - Produk apa yang paling banyak dan paling sedikit terjual?
# - Bagaimana demografi pelanggan yang kita miliki?

# %% [markdown]
# # Import Semua Packages/Library yang digunakan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ## Gathering Data
# **Pengumpulan Data**

# %%
customers_df = pd.read_csv('data/customers_dataset.csv')
customers_df.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
orders_df = pd.read_csv('data/orders_dataset.csv')
orders_df.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
order_items_df = pd.read_csv('data/order_items_dataset.csv')
order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
product_df = pd.read_csv('data/products_dataset.csv')
product_df.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
product_cat_name_df = pd.read_csv('data/product_category_name_translation.csv')
product_cat_name_df.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
seller_df = pd.read_csv('data/sellers_dataset.csv')
seller_df.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ## Assesing Data
# **Menilai Data**

# %% [markdown]
# ### Menilai Data customer_df

# %%
customers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
print("Jumlah Duplikasi : ", customers_df.duplicated().sum())
customers_df.describe()
# Out:
# Jumlah Duplikasi :  0
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %% [markdown]
# ### Menilai Data orders_df

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %% [markdown]
# Terdapat keanehan pada data di Columns **order_approved_at, order_delivered_carrier_date, order_delivered_customer_date**

# %%
print("Jumlah Duplikasi : ", orders_df.duplicated().sum())
orders_df.describe()
# Out:
# Jumlah Duplikasi :  0
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# ### Menilai Data order_items_df

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
print("Jumlah Duplikasi : ", order_items_df.duplicated().sum())
order_items_df.describe()
# Out:
# Jumlah Duplikasi :  0
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %% [markdown]
# ### Menilai Data product_df

# %%
product_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# Terdapat keanehan pada data pada informasi diatas

# %%
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
print("Jumlah Duplikasi : ", product_df.duplicated().sum())
product_df.describe()
# Out:
# Jumlah Duplikasi :  0
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# ...

# %% [markdown]
# ### Menilai Data product_cat_name_df

# %%
product_cat_name_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
print("Jumlah Duplikasi : ", product_cat_name_df.duplicated().sum())
product_cat_name_df.describe()
# Out:
# Jumlah Duplikasi :  0
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# ### Menilai Data seller_df

# %%
seller_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
print("Jumlah Duplikasi : ", product_cat_name_df.duplicated().sum())
product_cat_name_df.describe()
# Out:
# Jumlah Duplikasi :  0
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# ## Cleaning Data
#
# Terdapat beberapa data yang perlu dibersihkan yaitu :
# - Data order_df
# - Data product_df

# %% [markdown]
# ### Cleaning Data orders_df
# Missing Value dengan menggunakan teknik filtering dan mengidentifikasi nilai dominan untuk mengganti Missing Value

# %%
orders_df[orders_df.order_approved_at.isna()]
# Out:
#                                order_id                       customer_id  \
# 1130   00b1cb0320190ca0daa2c88b35206009  3532ba38a3fd242259a514ac2b6ae6b6
# 1801   ed3efbd3a87bea76c2812c66a0b32219  191984a8ba4cbb2145acb4fe35b69664
# 1868   df8282afe61008dc26c6c31011474d02  aa797b187b5466bc6925aaaa4bb3bed1
# 2029   8d4c637f1accf7a88a4555f02741e606  b1dd715db389a2077f43174e7a675d07
# 2161   7a9d4c7f9b068337875b95465330f2fc  7f71ae48074c0cfec9195f88fcbfac55
# ...                                 ...                               ...
# 97696  5a00b4d35edffc56b825c3646a99ba9d  6a3bdf004ca96338fb5fad1b8d93c2e6
# 98415  227c804e2a44760671a6a5697ea549e4  62e7477e75e542243ee62a0ba73f410f
# 98909  e49e7ce1471b4693482d40c2bd3ad196  e4e7ab3f449aeb401f0216f86c2104db
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
#
#       order_status order_purchase_timestamp order_approved_at  \
# ...

# %%
# Nilai Dominan
orders_df.order_approved_at.value_counts()
# Out:
# order_approved_at
# 2018-02-27 04:31:10    9
# 2017-11-07 07:30:38    7
# 2018-02-27 04:31:01    7
# 2018-02-06 05:31:52    7
# 2017-11-07 07:30:29    7
#                       ..
# 2018-08-22 11:50:14    1
# 2017-09-22 11:27:36    1
# 2018-03-07 16:40:32    1
# 2017-08-08 10:50:15    1
# 2018-03-09 11:20:28    1
# Name: count, Length: 90733, dtype: int64

# %%
# Mengatasi Missing Value dengan mengganti ke Nilai Dominan
orders_df.fillna(value="2018-02-27 04:31:10", inplace=True)

# %%
orders_df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_approved_at                0
# order_delivered_carrier_date     0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# dtype: int64

# %% [markdown]
# ### Cleaning Data product_df
# Missing Value dengan menggunakan teknik filtering dan mengidentifikasi nilai dominan untuk mengganti Missing Value
# Berikut data yang mengandung Missing Value :
# - product_category_name
# - product_name_lenght
# - product_description_lenght
# - product_photos_qty
# - product_weight_g
# - product_length_cm
# - product_height_cm
# - product_width_cm

# %% [markdown]
# **Filtering Data Missing Value**

# %%
# product_category_name
# Teknik flitering guna mengidentifikasi data yang memiliki Missing Value
print(product_df[product_df.product_category_name.isna()])
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
# product_name_lenght
# Teknik flitering guna mengidentifikasi data yang memiliki Missing Value
print(product_df[product_df.product_name_lenght.isna()])
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
# product_description_lenght
# Teknik flitering guna mengidentifikasi data yang memiliki Missing Value
print(product_df[product_df.product_description_lenght.isna()])
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
# product_photos_qty
# Teknik flitering guna mengidentifikasi data yang memiliki Missing Value
print(product_df[product_df.product_photos_qty.isna()])
# Out:
#                              product_id product_category_name  \
# 105    a41e356c76fab66334f36de622ecbd3a                   NaN
# 128    d8dee61c2034d6d075997acef1870e9b                   NaN
# 145    56139431d72cd51f19eb9f7dae4d1617                   NaN
# 154    46b48281eb6d663ced748f324108c733                   NaN
# 197    5fb61f482620cb672f5e586bb132eae9                   NaN
# ...                                 ...                   ...
# 32515  b0a0c5dd78e644373b199380612c350a                   NaN
# 32589  10dbe0fbaa2c505123c17fdc34a63c56                   NaN
# 32616  bd2ada37b58ae94cc838b9c0569fecd8                   NaN
# 32772  fa51e914046aab32764c41356b9d4ea4                   NaN
# 32852  c4ceee876c82b8328e9c293fa0e1989b                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 105                    NaN                         NaN                 NaN
# ...

# %%
# product_weight_g
# Teknik flitering guna mengidentifikasi data yang memiliki Missing Value
print(product_df[product_df.product_weight_g.isna()])
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %%
# product_length_cm
# Teknik flitering guna mengidentifikasi data yang memiliki Missing Value
print(product_df[product_df.product_length_cm.isna()])
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %%
# product_height_cm
# Teknik flitering guna mengidentifikasi data yang memiliki Missing Value
print(product_df[product_df.product_height_cm.isna()])
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %%
# product_width_cm
# Teknik flitering guna mengidentifikasi data yang memiliki Missing Value
print(product_df[product_df.product_width_cm.isna()])
# Out:
#                              product_id product_category_name  \
# 8578   09ff539a621711667c43eba6a3bd8466                 bebes
# 18851  5eb564652db742ff8f28759cd8d2652a                   NaN
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 8578                  60.0                       865.0                 3.0
# 18851                  NaN                         NaN                 NaN
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 8578                NaN                NaN                NaN
# 18851               NaN                NaN                NaN
#
#        product_width_cm
# 8578                NaN
# 18851               NaN

# %% [markdown]
# **Identifikasi Nilai Dominan**

# %%
# product_df_category_name
# identifikasi nilai Dominan untuk menggantikan Missing Value

print(product_df.product_category_name.value_counts())
# Out:
# product_category_name
# cama_mesa_banho                  3029
# esporte_lazer                    2867
# moveis_decoracao                 2657
# beleza_saude                     2444
# utilidades_domesticas            2335
#                                  ...
# fashion_roupa_infanto_juvenil       5
# casa_conforto_2                     5
# pc_gamer                            3
# seguros_e_servicos                  2
# cds_dvds_musicais                   1
# Name: count, Length: 73, dtype: int64

# %%
# product_name_lenght
# identifikasi nilai Dominan untuk menggantikan Missing Value

print(product_df.product_name_lenght.value_counts())
# Out:
# product_name_lenght
# 60.0    2182
# 59.0    2025
# 58.0    1887
# 57.0    1719
# 55.0    1683
#         ...
# 66.0       1
# 72.0       1
# 67.0       1
# 76.0       1
# 6.0        1
# Name: count, Length: 66, dtype: int64

# %%
# product_description_lenght
# identifikasi nilai Dominan untuk menggantikan Missing Value

print(product_df.product_description_lenght.value_counts())
# Out:
# product_description_lenght
# 404.0     94
# 729.0     86
# 651.0     66
# 703.0     66
# 236.0     65
#           ..
# 2795.0     1
# 2308.0     1
# 3698.0     1
# 3522.0     1
# 2207.0     1
# Name: count, Length: 2960, dtype: int64

# %%
# product_photos_qty
# identifikasi nilai Dominan untuk menggantikan Missing Value

print(product_df.product_photos_qty.value_counts())
# Out:
# product_photos_qty
# 1.0     16489
# 2.0      6263
# 3.0      3860
# 4.0      2428
# 5.0      1484
# 6.0       968
# 7.0       343
# 8.0       192
# 9.0       105
# 10.0       95
# 11.0       46
# 12.0       35
# 13.0        9
# 15.0        8
# 17.0        7
# 14.0        5
# 18.0        2
# 20.0        1
# 19.0        1
# Name: count, dtype: int64

# %%
# product_weight_g
# identifikasi nilai Dominan untuk menggantikan Missing Value

print(product_df.product_weight_g.value_counts())
# Out:
# product_weight_g
# 200.0     2084
# 300.0     1561
# 150.0     1259
# 400.0     1206
# 100.0     1188
#           ...
# 6075.0       1
# 822.0        1
# 631.0        1
# 2925.0       1
# 1920.0       1
# Name: count, Length: 2204, dtype: int64

# %%
# product_length_cm
# identifikasi nilai Dominan untuk menggantikan Missing Value

print(product_df.product_length_cm.value_counts())
# Out:
# product_length_cm
# 16.0    5520
# 20.0    2816
# 30.0    2029
# 18.0    1502
# 25.0    1387
#         ...
# 96.0       4
# 10.0       3
# 8.0        2
# 9.0        2
# 7.0        1
# Name: count, Length: 99, dtype: int64

# %%
# product_height_cm
# identifikasi nilai Dominan untuk menggantikan Missing Value

print(product_df.product_height_cm.value_counts())
# Out:
# product_height_cm
# 10.0    2548
# 15.0    2022
# 20.0    1991
# 16.0    1595
# 11.0    1551
#         ...
# 98.0       2
# 97.0       2
# 99.0       1
# 89.0       1
# 94.0       1
# Name: count, Length: 102, dtype: int64

# %%
# product_width_cm
# identifikasi nilai Dominan untuk menggantikan Missing Value

print(product_df.product_width_cm.value_counts())
# Out:
# product_width_cm
# 11.0     3718
# 20.0     3053
# 16.0     2808
# 15.0     2393
# 30.0     1786
#          ...
# 103.0       1
# 86.0        1
# 98.0        1
# 87.0        1
# 104.0       1
# Name: count, Length: 95, dtype: int64

# %% [markdown]
# **Mengganti Missing Value menggunakan nilai Dominan masing masing Column Data**

# %%
# poduct_category_name
print(product_df.product_category_name.fillna(value="cama_mensa_banho", inplace=True))
# Out:
# None

# %%
# product_name_lenght
product_df['product_name_lenght'].fillna(value=60.0, inplace=True)

# %%
# product_description_lenght
product_df['product_description_lenght'].fillna(value=404.0, inplace=True)

# %% [markdown]
# **Memastikan Missing Value pada 3 data di atas**

# %%
# periksa kembali missing value
product_df.isna().sum()
# Out:
# product_id                      0
# product_category_name           0
# product_name_lenght             0
# product_description_lenght      0
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# Tiga data missing value diatas sudah berhasil diatasi selanjutnya mengatasi kembali missing value dari 5 data tersisa

# %%
# product_photos_qty
product_df['product_photos_qty'].fillna(value=1.0, inplace=True)

# %%
# product_weight_g
product_df['product_weight_g'].fillna(value=200.0, inplace=True)

# %%
# product_length_cm
product_df['product_length_cm'].fillna(value=16.0, inplace=True)

# %% [markdown]
# **Memastikan Missing Value pada 3 data di atas**

# %%
product_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             2
# product_width_cm              2
# dtype: int64

# %% [markdown]
# Tiga data missing value diatas sudah berhasil diatasi selanjutnya mengatasi kembali missing value dari 2 data tersisa

# %%
# product_height_cm
product_df['product_height_cm'].fillna(value=10.0, inplace=True)

# %%
# product_width_cm
product_df['product_width_cm'].fillna(value=10.0, inplace=True)

# %% [markdown]
# **Memastikan Missing Value pada keseleuruhan data product_df**

# %%
product_df.isna().sum()
# Out:
# product_id                    0
# product_category_name         0
# product_name_lenght           0
# product_description_lenght    0
# product_photos_qty            0
# product_weight_g              0
# product_length_cm             0
# product_height_cm             0
# product_width_cm              0
# dtype: int64

# %% [markdown]
# Semua Missing Value sudah teratasi.

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Eksplorasi Data customer_df

# %% [markdown]
# Melihat rangkuman parameter ststistik dari data customers_df menggunakan metode describe()

# %%
customers_df.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers_df.sample(10)
# Out:
#                             customer_id                customer_unique_id  \
# 44399  c6493ae5b5ae563a2a20a534dfd21cb8  d89bbed2bfc8b18edbd8fa87c7e214e1
# 52847  371d4dbc5b397a2d011aeeba1580f194  92ebe191297a15dbd82c79561d5e1bdc
# 1515   8f2b91ff30c5a34e638e218fe902b758  bcaedda052fc72c42f55dd7c28b4b38e
# 41030  71fd52295abb1b8c1cd4da93dce20bb8  f700c475c69e4402aeaf4b55d531a2b2
# 72112  1288df1d9da5e124c94b06a6ba3ca50b  2cbb27285e259123d5b9aac321b7085e
# 49429  7c8df632741577655c609c9d71b69720  789399a42b8759f374cc489d7c799090
# 40938  99923b03e0bcc01975a71c7ae9a79942  3d75cbf8643a1c15723adb850fb5f928
# 60060  e7b950a8f7872df50ab618d052437d84  b0d507d4f0e77d9e0082adf8e25a71e8
# 12841  153b331aeacbfe9836a87b7d75a4bb2c  c054ecafd9a406747428899b48fd7447
# 38999  a11e1fd66f38ab316781473a2fc2474c  aa2ffc76040384f4dcc63d1ff2bbe4ff
#
#        customer_zip_code_prefix               customer_city customer_state
# 44399                     24805                    itaborai             RJ
# ...

# %% [markdown]
# Dari data **customer_df** maka dapat melihat demografi pelanggan berdasarkan city (Kota) dan state (Negara) mengggunakan metode grouby() dan agg()

# %% [markdown]
# **Demografi Pelanggan berdasarkan Kota (City)**

# %%
customers_df.groupby(by="customer_city").agg({
    "customer_id": "nunique",
})
# Out:
#                      customer_id
# customer_city
# abadia dos dourados            3
# abadiania                      1
# abaete                        12
# abaetetuba                    11
# abaiara                        2
# ...                          ...
# xinguara                       9
# xique-xique                    3
# zacarias                       2
# ze doca                        5
# zortea                         2
#
# [4119 rows x 1 columns]

# %%
customers_df.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %% [markdown]
# Dari rangkuman data customer_df pada column **customer_city** menunjukan bahwa demografi pelanggan berdasarkan kota terbanyak berada di **Sao Paulo** dan paling sedikit berjumlah satu yaitu **lagoao**

# %% [markdown]
# **Demografi Pelanggan berdasarkan State**

# %%
customers_df.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# ## Eksplorasi data orders_df dan customer_df

# %% [markdown]
# Melihat rangkuman parameter ststistik dari data orders_df menggunakan metode describe()

# %%
orders_df.sample(5)
# Out:
#                                order_id                       customer_id  \
# 25363  17a3d477ebcd2f70cf12135d4e07fb17  4ad966e1eefc576c04159e46a8e38b20
# 89267  659a4b8e5c9540667f4d4d5607bc8f79  a74f74bbbb5f762dbe2f38bff34d3e40
# 65841  5f24b613363e4af7466a250aa815a170  1a475ff9958a875936b3da7c7367212c
# 33428  34fa15662de2057126fbb0b0f1c1120f  d79f039ffbcb11e3ffe7410595788f03
# 49040  098f15b40cb74aae030d56b720c5698c  9662a6e2918ac93d63f687e51219d027
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 25363    delivered      2018-01-10 18:35:19  2018-01-12 02:37:37
# 89267    delivered      2018-03-06 11:18:36  2018-03-06 12:00:31
# 65841    delivered      2018-07-23 10:37:56  2018-07-23 13:24:30
# 33428    delivered      2017-11-27 20:41:04  2017-11-27 20:59:33
# 49040    delivered      2018-01-26 17:26:30  2018-01-26 17:39:47
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# ...

# %% [markdown]
# Pada data orders_df terdapat kolom yang berisi informasi terkait customer_id pelanggan yang pernah melakukan order. Informasi tersebut bisa digunakan untuk mengidentifikasi pelanggan yang belum pernah melakukan order. Guna melakukan hal tersebut maka dibuatkan sebuah kolom baru bernama **status** pada data customers_df. Kolom tersebut memiliki nilai **Active** untuk pelanggan yang pernah melakukan order dan **Non Active** untuk pelanggan yang belum pernah melakukan order sama sekali.

# %%
customer_id_in_orders_df = orders_df.customer_id.tolist()
customers_df["status"] = customers_df["customer_id"].apply(lambda x: "Active" if x in customer_id_in_orders_df else "Non Active")
customers_df.sample(5)
# Out:
#                             customer_id                customer_unique_id  \
# 52400  35c5fd514f5eed2913f71df5a01451f2  34659ca36aa8e8becbc3a6d51da54364
# 84292  fccc0ac1e7e53ba3df6e2b03dfb18c21  b4e686faf1cb6dab11c2dd46338e97b5
# 94828  4c905422f491aa302e218b77cc8b3e88  e3828c5fa1f5cf7d01c462c465606f0c
# 15898  dc1fa8bf46a0b4afeb55416fbec4e690  53d6b9cc99f62289555aa1666c389282
# 8513   c5cec2f88aa92fc22fae96e287c61ff9  3136c4d6231ed845c91d5e1959f76437
#
#        customer_zip_code_prefix   customer_city customer_state  status
# 52400                     91260    porto alegre             RS  Active
# 84292                      1225       sao paulo             SP  Active
# 94828                      7084       guarulhos             SP  Active
# 15898                     22261  rio de janeiro             RJ  Active
# 8513                      13181          sumare             SP  Active

# %% [markdown]
# **Menghitung status customer**

# %%
customers_df.groupby("status").customer_id.count()
# Out:
# status
# Active    99441
# Name: customer_id, dtype: int64

# %% [markdown]
# Dari informasi tersebut seluruh pelanggan berstatus Active 100% kemudian untuk informasi lebih lengkap maka menggunakan merge dan join antara orders_df dan customers_df.

# %%
orders_customers_df = pd.merge(
    left=orders_df,
    right=customers_df,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
orders_customers_df.head(10)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# 5  a4591c265e18cb1dcee52889e2d8acc3  503740e9ca751ccdda7ba28e9ab8f608
# 6  136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 7  6514b8ad8028c9f2cc2374ded245783f  9bdf08b4b3b52b5526ff42d37d47f222
# 8  76c6e866289321a7c93b82b54852dc33  f54a9f0e6b351c431402b8461ea51999
# 9  e69bfb5eb88e0ed6a785585b27e16dbf  31ad1d1b63eb9962463f764d4e6e0c9d
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# ...

# %% [markdown]
# Berdasarkan merge dan join orders_df dan customers_df dapat diperoleh informasi order berdasarkan city (Kota) dan state (Negara)

# %%
orders_customers_df.groupby(by="customer_city").order_id.nunique().sort_values(ascending=False).reset_index().head()
# Out:
#     customer_city  order_id
# 0       sao paulo     15540
# 1  rio de janeiro      6882
# 2  belo horizonte      2773
# 3        brasilia      2131
# 4        curitiba      1521

# %%
orders_customers_df.groupby(by="customer_state").order_id.nunique().sort_values(ascending=False).reset_index().head()
# Out:
#   customer_state  order_id
# 0             SP     41746
# 1             RJ     12852
# 2             MG     11635
# 3             RS      5466
# 4             PR      5045

# %% [markdown]
# Dari indormasi yang diperoleh **sao paulo** menjadi city paling banyak order_id dan **SP** menjadi state paling banyak order_id

# %% [markdown]
# ## Eksplorasi Data product_df dan order_items_df

# %%
order_items_df.sort_values(by="price", ascending=False)
# Out:
#                                 order_id  order_item_id  \
# 3556    0812eb902a67711a1cb742b3cdaa65ae              1
# 112233  fefacc66af859508bf1a7934eab1e97f              1
# 107841  f5136e38d1a14a4dbd87dff67da82701              1
# 74336   a96610ab360d42a2e5335a3998b4718a              1
# 11249   199af31afc78c699f0dbf71fb178d4d4              1
# ...                                  ...            ...
# 57304   8272b63d03f5f79c56e9e4120aec44ef              8
# 57300   8272b63d03f5f79c56e9e4120aec44ef              4
# 48625   6e864b3f0ec71031117ad4cf46b7f2a1              1
# 27652   3ee6513ae7ea23bdfab5b9ab60bffcb5              1
# 87081   c5bdd8ef3c0ec420232e668302179113              2
#
#                               product_id                         seller_id  \
# 3556    489ae2aa008f021502940f251d4cce7f  e3b4998c7a498169dc7bce44e6bb6277
# 112233  69c590f7ffc7bf8db97190b6cb6ed62e  80ceebb4ee9b31afb6c6a916a574a1e2
# ...

# %% [markdown]
# Berdasarkan data order_items_df dapat dieksplorasi lebih mendalam dengan melakukan merger dan join antara data product_df dan order_items_df

# %%
product_order_items_df = pd.merge(
    left=order_items_df,
    right=product_df,
    how="left",
    left_on="product_id",
    right_on="product_id"
)

product_order_items_df.head(10)
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
# 5  00048cc3ae777c65dbb7d2a0634bc1ea              1
# 6  00054e8431b9d7675808bcb819fb4a32              1
# 7  000576fe39319847cbb9d288c5617fa6              1
# 8  0005a1a1728c9d785b8e2b08b904576c              1
# 9  0005f50442cb953dcd1d21e1fb923495              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# ...

# %%
product_order_items_df.groupby(by="product_category_name").agg({
    "product_id": "nunique",
    "freight_value": "sum",
    "price": ["min","max"]
})
# Out:
#                           product_id freight_value  price
#                              nunique           sum    min      max
# product_category_name
# agro_industria_e_comercio         74       5843.60  12.99  2990.00
# alimentos                         82       7271.03   9.99   274.99
# alimentos_bebidas                104       4507.99   6.50   699.90
# artes                             55       4045.17   3.50  6499.00
# artes_e_artesanato                19        370.13   9.80   289.49
# ...                              ...           ...    ...      ...
# sinalizacao_e_seguranca           93       6507.82   4.50   740.00
# tablets_impressao_imagem           9       1226.20  14.90   889.99
# telefonia                       1134      71215.79   5.00  2428.00
# telefonia_fixa                   116       4637.81   6.00  1790.00
# utilidades_domesticas           2335     146149.11   3.06  6735.00
#
# [74 rows x 4 columns]

# %% [markdown]
# ## Eksplorasi Data seller_df

# %%
seller_df.describe(include="all")
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %% [markdown]
# Untuk mengetahui seller yang paling sering menerima order berdasarkan city dan state dapat dilakukan denga merge dan join antara order_items_df dan seller_df

# %%
seller_order_items_df = pd.merge(
    left=order_items_df,
    right=seller_df,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)

seller_order_items_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value  seller_zip_code_prefix  \
# 0  2017-09-19 09:45:35   58.90          13.29                   27277
# 1  2017-05-03 11:05:13  239.90          19.93                    3471
# ...

# %% [markdown]
# **order_id seller berdasarkan kota**

# %%
seller_order_items_df.groupby(by="seller_city").order_id.nunique().sort_values(ascending=False).reset_index().head(5)
# Out:
#       seller_city  order_id
# 0       sao paulo     24588
# 1        ibitinga      6565
# 2        curitiba      2722
# 3     santo andre      2711
# 4  belo horizonte      2414

# %% [markdown]
# **order_id seller berdasarkan state**

# %%
seller_order_items_df.groupby(by="seller_state").order_id.nunique().sort_values(ascending=False).reset_index().head(5)
# Out:
#   seller_state  order_id
# 0           SP     70188
# 1           MG      7930
# 2           PR      7673
# 3           RJ      4353
# 4           SC      3667

# %% [markdown]
# ## Eksplorasi Data all_df

# %%
all_df = pd.merge(
    left=product_order_items_df,
    right=orders_customers_df,
    how="left",
    left_on="order_id",
    right_on="order_id"
)

all_df.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value product_category_name  \
# 0  2017-09-19 09:45:35   58.90          13.29            cool_stuff
# 1  2017-05-03 11:05:13  239.90          19.93              pet_shop
# ...

# %% [markdown]
# Menggali informasi preferensi pelanggan berdasarkan state pelanggan dan namaproduct

# %%
all_df.groupby(by=["customer_state", "product_category_name"]).agg({
    "freight_value": "sum",
    "price": "sum"
})
# Out:
#                                             freight_value    price
# customer_state product_category_name
# AC             artigos_de_natal                     60.95    69.90
#                automotivo                          120.93   540.98
#                bebes                               174.13   697.84
#                beleza_saude                        268.42  1386.58
#                brinquedos                           83.26   234.79
# ...                                                   ...      ...
# TO             portateis_casa_forno_e_cafe          95.44  1999.00
#                relogios_presentes                  950.02  5446.89
#                telefonia                           627.34  1268.12
#                telefonia_fixa                       53.58  1390.99
#                utilidades_domesticas               484.74  1275.75
#
# [1394 rows x 2 columns]

# %% [markdown]
# # Visualization & Explanatory Analysis

# %% [markdown]
# ## Pertanyaan 1 : Produk apa yang paling banyak dan paling sedikit terjual?

# %%
sum_order_items_df = all_df.groupby(by="product_category_name").order_item_id.sum().sort_values(ascending=False).reset_index()
sum_order_items_df.head(10)
# Out:
#     product_category_name  order_item_id
# 0         cama_mesa_banho          13665
# 1        moveis_decoracao          11540
# 2            beleza_saude          11081
# 3           esporte_lazer           9932
# 4  informatica_acessorios           9874
# 5   utilidades_domesticas           9051
# 6      relogios_presentes           6594
# 7      ferramentas_jardim           5874
# 8               telefonia           5161
# 9              automotivo           4881

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24, 6))

plt.suptitle("Best and Worst Performing Product by Number of Sales", fontsize=24)
colors = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]

sns.barplot(x="order_item_id", y="product_category_name", data=sum_order_items_df.head(5), palette=colors, ax=ax[0], hue="product_category_name", legend=False)
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product", loc="center", fontsize=15)
ax[0].tick_params(axis ='y', labelsize=12)

sns.barplot(x="order_item_id", y="product_category_name", data=sum_order_items_df.sort_values(by="order_item_id", ascending=True).head(5), palette=colors, ax=ax[1],hue="product_category_name", legend=False)
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product", loc="center", fontsize=15)
ax[1].tick_params(axis='y', labelsize=12)

plt.show()

# %% [markdown]
# ## Pertanyaan 2 : Bagaimana demografi pelanggan yang kita miliki?

# %%
bystate_df = all_df.groupby(by="customer_state").customer_id.nunique().reset_index()
bystate_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
bystate_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", 
           "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", 
           "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", 
           "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="customer_count",
    y="customer_state",
    data=bystate_df.sort_values(by="customer_count", ascending=False),
    palette=colors_,
    hue="customer_state",
    legend=False
)
plt.title("Number of Customer by States", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()

# %%
bycity_df = all_df.groupby(by="customer_city").customer_id.nunique().reset_index()
bycity_df.rename(columns={
    "customer_id": "customer_count"
}, inplace=True)
bycity_df
plt.figure(figsize=(10, 5))
colors_ = ["#72BCD4", "#D3D3D3", "#D3D3D3", "#D3D3D3", "#D3D3D3"]
sns.barplot(
    x="customer_count",
    y="customer_city",
    data=bycity_df.sort_values(by="customer_count", ascending=False).head(5),
    palette=colors_,
    hue="customer_city",
    legend=False
)
plt.title("Best Number of Customer by City", loc="center", fontsize=15)
plt.ylabel(None)
plt.xlabel(None)
plt.tick_params(axis='y', labelsize=12)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# ## Petanyaan 1 : Produk apa yang paling banyak dan paling sedikit terjual?
# Berdasarkan visualisasi data yang sudah di tunjukan 5 produk category terlaris yaitu **cama_mesa_baho, moveis_decoracao, beleza_saude, esporte_lazer, dan informatica_acessorios**. Kemudian 5 produk paling sedikit yaitu **seguro_e_servicos, fashion_roupa_infanto_juvenil, pc_gamer, cds_dvds_musicais, la_cuisine**.

# %% [markdown]
# ## Pertanyaan 2 : Bagaimana demografi pelanggan yang kita miliki?
# Berdasarkan visualisasi data yang sudah ditunjukan customer paling banyak berada di code state **SP** dan paling sedikit di code state **RR** dan Angka terbaik customer berdasarkan city (Kota) berada di **Sao Paulo disusul dengan Rio De Janeiero, Belo Horizonte, Brasilia, dan Curitiba**.

# %%
all_df.to_csv("all_data.csv", index=False)
